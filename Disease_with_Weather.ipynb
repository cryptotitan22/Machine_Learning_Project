# %% [markdown]
# <a href="https://colab.research.google.com/github/cryptotitan22/Machine_Learning_Project/blob/main/Disease_with_Weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Disease with Weather.csv")
df
# Out:
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0            18.7        77         6.9            63        11.0    1015.5
# 1            23.4        64         4.6           137         8.9    1017.0
# 2            20.1        72         3.2           188        10.0    1014.8
# 3            25.6        61         7.1           282         9.6    1015.2
# 4            19.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# 4015         21.3        75         3.9           131        11.9    1015.6
# 4016         25.1        67         7.4           257         8.4    1016.0
# 4017         19.7        79         4.0            93        11.1    1014.5
# 4018         28.3        58         9.6           354         8.8    1015.4
# 4019         26.2        62         8.0           248         9.0    1015.5
#
#            Disease  Disease in number
# ...

# %%
df.shape
# Out:
# (4020, 8)

# %%
df.isnull().sum()
# Out:
# Temperature          0
# Humidity             0
# Wind Speed           0
# Wind Bearing         0
# Visibility           0
# Pressure             0
# Disease              0
# Disease in number    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df.Disease	= label.fit_transform(df.Disease)
df.Disease
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 4015    0
# 4016    1
# 4017    0
# 4018    1
# 4019    0
# Name: Disease, Length: 4020, dtype: int64

# %%
df
# Out:
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0            18.7        77         6.9            63        11.0    1015.5
# 1            23.4        64         4.6           137         8.9    1017.0
# 2            20.1        72         3.2           188        10.0    1014.8
# 3            25.6        61         7.1           282         9.6    1015.2
# 4            19.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# 4015         21.3        75         3.9           131        11.9    1015.6
# 4016         25.1        67         7.4           257         8.4    1016.0
# 4017         19.7        79         4.0            93        11.1    1014.5
# 4018         28.3        58         9.6           354         8.8    1015.4
# 4019         26.2        62         8.0           248         9.0    1015.5
#
#       Disease  Disease in number
# ...

# %%
x = df.drop(['Disease'],axis=1)
x
# Out:
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0            18.7        77         6.9            63        11.0    1015.5
# 1            23.4        64         4.6           137         8.9    1017.0
# 2            20.1        72         3.2           188        10.0    1014.8
# 3            25.6        61         7.1           282         9.6    1015.2
# 4            19.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# 4015         21.3        75         3.9           131        11.9    1015.6
# 4016         25.1        67         7.4           257         8.4    1016.0
# 4017         19.7        79         4.0            93        11.1    1014.5
# 4018         28.3        58         9.6           354         8.8    1015.4
# 4019         26.2        62         8.0           248         9.0    1015.5
#
#       Disease in number
# 0                     1
# ...

# %%
y = df['Disease']
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 4015    0
# 4016    1
# 4017    0
# 4018    1
# 4019    0
# Name: Disease, Length: 4020, dtype: int64

# %%
xtest
# Out:
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 1078         27.0        58         8.5           340         8.8    1015.2
# 2584         27.3        58         8.1           309         8.6    1014.4
# 706          19.1        73         4.6           108        11.8    1015.0
# 1248         20.8        75         4.4            94        12.1    1015.7
# 2355         24.0        68         3.5           228         9.7    1014.0
# ...           ...       ...         ...           ...         ...       ...
# 895          27.5        61         6.6           293         8.9    1015.2
# 553          24.3        65         2.3           230         9.7    1014.0
# 1098         28.0        58         9.4            37         8.3    1014.6
# 2094         26.9        61         6.4           312         8.4    1016.1
# 2727         27.0        61         7.9           302         9.2    1015.5
#
#       Disease in number
# 1078                  0
# ...

# %%
ytrain
# Out:
# 1220    1
# 559     1
# 2494    0
# 3893    0
# 2837    0
#        ..
# 835     1
# 3264    0
# 1653    1
# 2607    0
# 2732    0
# Name: Disease, Length: 3216, dtype: int64

# %%
ytest
# Out:
# 1078    1
# 2584    1
# 706     0
# 1248    0
# 2355    1
#        ..
# 895     1
# 553     1
# 1098    1
# 2094    1
# 2727    1
# Name: Disease, Length: 804, dtype: int64

# %%
from sklearn.svm import SVC
model = SVC(gamma='auto')

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC(gamma='auto')

# %%
model.score(xtest,ytest)
# Out:
# 0.9763681592039801

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn = knn.fit(xtrain,ytrain)
knn
# Out:
# KNeighborsClassifier()

# %%
knn = knn.score(xtest,ytest)
knn
# Out:
# 0.9738805970149254

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier()
RFC.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
RFC.score(xtest,ytest)
# Out:
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()
DTC.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
DTC.score(xtest,ytest)
# Out:
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
LG = LogisticRegression()
LG.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LG.score(xtest,ytest)
# Out:
# 0.9838308457711443
